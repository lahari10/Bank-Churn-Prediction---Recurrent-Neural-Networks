# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"C:\Users\Ram Chander\Downloads\bank_churn.csv")
df
# Out:
#        userid  churn  age rent_or_own  trivia_played  trivia_shared_results  \
# 0           0      1   22          na              0                      0
# 1           7      1   25           R              0                      0
# 2           8      1   32          na              0                      0
# 3          18      1   26          na              0                      0
# 4          19      1   28           R              0                      0
# ...       ...    ...  ...         ...            ...                    ...
# 48074    4950      0   42          na              0                      0
# 48075   30078      0   38           O              0                      0
# 48076   39581      0   20           R              5                      0
# 48077    3036      0   27           R              0                      0
# 48078   10687      0   33           R              3                      2
#
# ...

# %%
df.drop(['userid','trivia_played','trivia_shared_results'],axis=1,inplace=True)

# %%
df.drop(['trivia_view_unlocked','trivia_view_results','zodiac_sign'],axis=1,inplace=True)

# %%
df
# Out:
#        churn  age rent_or_own  cards_share  cards_viewed  cards_helpful  \
# 0          1   22          na            0            48              0
# 1          1   25           R            0             5              0
# 2          1   32          na            0            49              0
# 3          1   26          na            0           184              0
# 4          1   28           R            0            65              0
# ...      ...  ...         ...          ...           ...            ...
# 48074      0   42          na            0             6              0
# 48075      0   38           O            0           207              0
# 48076      0   20           R            0           132              0
# 48077      0   27           R            0           143              0
# 48078      0   33           R            0            20              0
#
#        cards_not_helpful  cards_clicked  has_used_mobile  has_used_web  ...  \
# ...

# %%
df.drop(['has_used_mobile','has_used_web'],axis=1,inplace=True)
df
# Out:
#        churn  age rent_or_own  cards_share  cards_viewed  cards_helpful  \
# 0          1   22          na            0            48              0
# 1          1   25           R            0             5              0
# 2          1   32          na            0            49              0
# 3          1   26          na            0           184              0
# 4          1   28           R            0            65              0
# ...      ...  ...         ...          ...           ...            ...
# 48074      0   42          na            0             6              0
# 48075      0   38           O            0           207              0
# 48076      0   20           R            0           132              0
# 48077      0   27           R            0           143              0
# 48078      0   33           R            0            20              0
#
#        cards_not_helpful  cards_clicked  used_android  used_ios  \
# ...

# %%
df.drop(['used_android','used_ios', 'more_than_one_mobile_device'],axis=1,inplace=True)

# %%
df.drop(['rent_or_own','cards_not_helpful'],axis=1,inplace=True)

# %%
df.keys()
# Out:
# Index(['churn', 'age', 'cards_share', 'cards_viewed', 'cards_helpful',
#        'cards_clicked', 'payfreq', 'loan_pending', 'withdrawn_application',
#        'paid_off_loan', 'did_not_accept_funding', 'un_linked_account',
#        're_linked_account', 'cash_back_engagement', 'has_referred'],
#       dtype='object')

# %%
sns.heatmap(df.isnull(), cmap='plasma')

# %%
sns.countplot(x='has_referred', data=df)

# %%
df.drop(['cards_share'],axis=1,inplace=True)

# %%
df.drop(['cards_viewed','cards_helpful'],axis=1,inplace=True)

# %%
df
# Out:
#        churn  age  cards_clicked       payfreq  loan_pending  \
# 0          1   22             11        Weekly             0
# 1          1   25              1        Weekly             0
# 2          1   32              2     Bi-Weekly             0
# 3          1   26             10            na             0
# 4          1   28              0            na             0
# ...      ...  ...            ...           ...           ...
# 48074      0   42              1  Semi-Monthly             1
# 48075      0   38             36        Weekly             0
# 48076      0   20             19        Weekly             0
# 48077      0   27             14            na             0
# 48078      0   33              7     Bi-Weekly             0
#
#        withdrawn_application  paid_off_loan  did_not_accept_funding  \
# 0                          0              0                       0
# 1                          0              0                       0
# ...

# %%
df.drop(['cards_clicked'],axis=1,inplace=True)

# %%
df
# Out:
#        churn  age       payfreq  loan_pending  withdrawn_application  \
# 0          1   22        Weekly             0                      0
# 1          1   25        Weekly             0                      0
# 2          1   32     Bi-Weekly             0                      0
# 3          1   26            na             0                      0
# 4          1   28            na             0                      0
# ...      ...  ...           ...           ...                    ...
# 48074      0   42  Semi-Monthly             1                      0
# 48075      0   38        Weekly             0                      0
# 48076      0   20        Weekly             0                      0
# 48077      0   27            na             0                      0
# 48078      0   33     Bi-Weekly             0                      0
#
#        paid_off_loan  did_not_accept_funding  un_linked_account  \
# 0                  0                       0                  0
# ...

# %%
df.drop(['loan_pending'],axis=1,inplace=True)

# %%
df.drop(['withdrawn_application'],axis=1,inplace=True)

# %%
df.keys()
# Out:
# Index(['churn', 'age', 'payfreq', 'paid_off_loan', 'did_not_accept_funding',
#        'un_linked_account', 're_linked_account', 'cash_back_engagement',
#        'has_referred'],
#       dtype='object')

# %%
freq_dummies=pd.get_dummies(df['payfreq'],drop_first=True)

# %%
df=pd.concat([df,freq_dummies],axis=1)

# %%
df
# Out:
#        churn  age       payfreq  paid_off_loan  did_not_accept_funding  \
# 0          1   22        Weekly              0                       0
# 1          1   25        Weekly              0                       0
# 2          1   32     Bi-Weekly              0                       0
# 3          1   26            na              0                       0
# 4          1   28            na              0                       0
# ...      ...  ...           ...            ...                     ...
# 48074      0   42  Semi-Monthly              0                       0
# 48075      0   38        Weekly              0                       0
# 48076      0   20        Weekly              0                       0
# 48077      0   27            na              0                       0
# 48078      0   33     Bi-Weekly              0                       0
#
#        un_linked_account  re_linked_account  cash_back_engagement  \
# ...

# %%
df.isnull()
# Out:
#        churn    age  payfreq  paid_off_loan  did_not_accept_funding  \
# 0      False  False    False          False                   False
# 1      False  False    False          False                   False
# 2      False  False    False          False                   False
# 3      False  False    False          False                   False
# 4      False  False    False          False                   False
# ...      ...    ...      ...            ...                     ...
# 48074  False  False    False          False                   False
# 48075  False  False    False          False                   False
# 48076  False  False    False          False                   False
# 48077  False  False    False          False                   False
# 48078  False  False    False          False                   False
#
#        un_linked_account  re_linked_account  cash_back_engagement  \
# 0                  False              False                 False
# ...

# %%
plt.figure(figsize=(12,10))
sns.boxplot(x='payfreq', y = 'age', data=df)

# %%
plt.figure(figsize=(12,10))
sns.boxplot(x='age', y = 'payfreq', data=df)

# %%
df.head(10)
# Out:
#    churn  age       payfreq  paid_off_loan  did_not_accept_funding  \
# 0      1   22        Weekly              0                       0
# 1      1   25        Weekly              0                       0
# 2      1   32     Bi-Weekly              0                       0
# 3      1   26            na              0                       0
# 4      1   28            na              0                       0
# 5      1   27  Semi-Monthly              0                       0
# 6      1   26        Weekly              0                       0
# 7      1   28  Semi-Monthly              0                       0
# 8      1   41     Bi-Weekly              0                       0
# 9      1   22            na              0                       0
#
#    un_linked_account  re_linked_account  cash_back_engagement  has_referred  \
# 0                  0                  0                  0.57             0
# ...

# %%
df.drop(['payfreq'],axis=1,inplace=True)

# %%
df
# Out:
#        churn  age  paid_off_loan  did_not_accept_funding  un_linked_account  \
# 0          1   22              0                       0                  0
# 1          1   25              0                       0                  0
# 2          1   32              0                       0                  0
# 3          1   26              0                       0                  0
# 4          1   28              0                       0                  0
# ...      ...  ...            ...                     ...                ...
# 48074      0   42              0                       0                  0
# 48075      0   38              0                       0                  0
# 48076      0   20              0                       0                  1
# 48077      0   27              0                       0                  0
# 48078      0   33              0                       0                  0
#
# ...

# %%
X=df.drop(['has_referred'],axis=1).values
y=df['has_referred'].values

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=1/3,random_state=1)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler(feature_range=(0,1))
df=scaler.fit_transform(np.array(df).reshape(-1,1))

# %%
X_train.shape
# Out:
# (32052, 11)

# %%
y_train.shape
# Out:
# (32052,)

# %%
X_train =X_train.reshape(X_train.shape[0],X_train.shape[1] , 1)
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1] , 1)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM

# %%
model=Sequential()
model.add(LSTM(50,return_sequences=True,input_shape=(100, 1)))
model.add(LSTM(50,return_sequences=True))
model.add(LSTM(50))
model.add(Dense(1))
model.compile(loss='mean_squared_error',optimizer='adam')

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# lstm (LSTM)                  (None, 100, 50)           10400
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 100, 50)           20200
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 50)                20200
# _________________________________________________________________
# dense (Dense)                (None, 1)                 51
# ...
# Total params: 50,851
# Trainable params: 50,851
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# lstm (LSTM)                  (None, 100, 50)           10400
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 100, 50)           20200
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 50)                20200
# _________________________________________________________________
# dense (Dense)                (None, 1)                 51
# ...
# Total params: 50,851
# Trainable params: 50,851
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X_train,y_train,validation_data=(X_test,y_test),epochs=100,batch_size=64,verbose=1)
# Out:
# Epoch 1/100
# WARNING:tensorflow:Model was constructed with shape (None, 100, 1) for input Tensor("lstm_input:0", shape=(None, 100, 1), dtype=float32), but it was called on an input with incompatible shape (None, 11, 1).
# WARNING:tensorflow:Model was constructed with shape (None, 100, 1) for input Tensor("lstm_input:0", shape=(None, 100, 1), dtype=float32), but it was called on an input with incompatible shape (None, 11, 1).
# ...
# 501/501 [==============================] - 23s 46ms/step - loss: 0.2141 - val_loss: 0.2090
# Epoch 2/100
# 501/501 [==============================] - 18s 36ms/step - loss: 0.2109 - val_loss: 0.2109
# Epoch 3/100
# 501/501 [==============================] - 21s 42ms/step - loss: 0.2096 - val_loss: 0.2064
# Epoch 4/100
# 501/501 [==============================] - 19s 38ms/step - loss: 0.2079 - val_loss: 0.2057
# Epoch 5/100
# 501/501 [==============================] - 18s 35ms/step - loss: 0.2066 - val_loss: 0.2062
# Epoch 6/100
# ...

# %%
train_predict=model.predict(X_train)
test_predict=model.predict(X_test)
# Out:
# WARNING:tensorflow:Model was constructed with shape (None, 100, 1) for input Tensor("lstm_input:0", shape=(None, 100, 1), dtype=float32), but it was called on an input with incompatible shape (None, 11, 1).

# %%
train_predict=scaler.inverse_transform(train_predict)
test_predict=scaler.inverse_transform(test_predict)

# %%
import math
from sklearn.metrics import mean_squared_error
math.sqrt(mean_squared_error(y_train,train_predict))
# Out:
# 33.37253880423955

# %%
math.sqrt(mean_squared_error(y_test,test_predict))
# Out:
# 33.366418908208644
